# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn import tree

# %%
path=r"Company_Data.csv"
df1=pd.read_csv(path)
df1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
df1.loc[df1['Sales'] > 10, ['Sales_df']]='high'

# %%
df1.loc[df1['Sales'] < 10, ['Sales_df']]='low'

# %%
df1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US Sales_df
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
categorical_columns=df1.select_dtypes(include=['object']).columns

# %%
categorical_columns
# Out:
# Index(['ShelveLoc', 'Urban', 'US', 'Sales_df'], dtype='object')

# %%
df1['ShelveLoc']=label.fit_transform(df1['ShelveLoc'])

# %%
df1['Urban']=label.fit_transform(df1['Urban'])

# %%
df1['US']=label.fit_transform(df1['US'])

# %%
df1.Sales_df.value_counts()
# Out:
# low     321
# high     78
# Name: Sales_df, dtype: int64

# %%
df1['Sales_df'].dtypes
# Out:
# dtype('O')

# %%
sales_df=pd.get_dummies(df1['Sales_df'],drop_first=True,prefix='sales_df')

# %%
sales_df
# Out:
#      sales_df_low
# 0               1
# 1               0
# 2               0
# 3               1
# 4               1
# ..            ...
# 395             0
# 396             1
# 397             1
# 398             1
# 399             1
#
# [400 rows x 1 columns]

# %%
df1=df1.drop('Sales_df',axis=1)
df1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          1   65
# 2    10.06        113      35           10         269     80          2   59
# 3     7.40        117     100            4         466     97          2   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          1   33
# 396   6.14        139      23            3          37    120          2   55
# 397   7.41        162      26           12         368    159          2   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          1   49
#
#      Education  Urban  US
# ...

# %%
df1=pd.concat([df1,sales_df],axis=1)

# %%
df1
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          1   65
# 2    10.06        113      35           10         269     80          2   59
# 3     7.40        117     100            4         466     97          2   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          1   33
# 396   6.14        139      23            3          37    120          2   55
# 397   7.41        162      26           12         368    159          2   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          1   49
#
# ...

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor

# %%
from sklearn.ensemble import BaggingClassifier

# %%
X=df1.iloc[:,1:-1]

# %%
y=df1.iloc[:,-1]

# %%
print(X)
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          0   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128          1   33
# 396        139      23            3          37    120          2   55
# 397        162      26           12         368    159          2   40
# 398        100      79            7         284     95          0   50
# 399        134      37            0          27    120          1   49
#
#      Education  Urban  US
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# ...

# %%
print(y)
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 395    0
# 396    1
# 397    1
# 398    1
# 399    1
# Name: sales_df_low, Length: 400, dtype: uint8

# %%
kfold=KFold(n_splits=10)

# %%
cart=DecisionTreeClassifier()

# %%
num_tress=100

# %%
model=BaggingClassifier(base_estimator=cart,n_estimators=num_tress)

# %%
results=cross_val_score(model,X,y,cv=kfold)

# %%
print(results.mean())
# Out:
# 0.8425

# %% [markdown]
# # Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model1=RandomForestClassifier(n_estimators=num_tress,max_features=3,)

# %%
results=cross_val_score(model1,X,y,cv=kfold)

# %%
print(results.mean())
# Out:
# 0.8525

# %% [markdown]
# # AdaBoost Classification

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model2=AdaBoostClassifier(n_estimators=10,random_state=7)

# %%
results=cross_val_score(model2,X,y,cv=kfold)

# %%
print(results.mean())
# Out:
# 0.8625

# %% [markdown]
# # Stacking

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier

# %%
kfold=KFold(n_splits=10,random_state=8)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(

# %%
estimators=[]
model3=LogisticRegression(max_iter=500)
estimators.append(('logistic',model3))

# %%
model4=DecisionTreeClassifier()

# %%
estimators.append(('cart',model4))

# %%
model5=SVC()

# %%
estimators.append(('svm',model5))

# %%
ensemble=VotingClassifier(estimators)

# %%
results=cross_val_score(ensemble,X,y,cv=kfold)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(results.mean())
# Out:
# 0.8350000000000002
